# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/envs/BME1/lib/python3.13/site-packages (from opencv-python) (2.1.3)
# Using cached opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np

def apply_color_mosaic(image, location=(50, 50), mosaic_size=(50, 50), color=(0, 255, 0)):
    """
    Applies a solid colored mosaic effect to an image.
    
    Parameters:
    - image (np.array): Input image.
    - location (tuple): (x, y) coordinates of the top-left corner where the mosaic will be applied.
    - mosaic_size (tuple): (width, height) of the mosaic area.
    - color (tuple): RGB color of the mosaic in (B, G, R) format.
    
    Returns:
    - Processed image with solid-colored mosaic effect.
    """
    x, y = location
    mosaic_width, mosaic_height = mosaic_size
    height, width = image.shape[:2]

    # Ensure the coordinates are within bounds
    if x + mosaic_width > width or y + mosaic_height > height:
        raise ValueError("Mosaic area exceeds image boundaries.")

    # Directly fill the ROI with the specified color to make it solid
    image[y:y + mosaic_height, x:x + mosaic_width] = color

    return image

def resize_image(image, target_size=(400, 400)):
    """
    Resizes the image to a fixed target size.
    
    Parameters:
    - image (np.array): Input image.
    - target_size (tuple): (width, height) to resize the image.
    
    Returns:
    - Resized image.
    """
    return cv2.resize(image, target_size, interpolation=cv2.INTER_AREA)

def process_dataset(input_base_dir, output_base_dir, target_size=(400, 400), mosaic_location=(100, 100), mosaic_size=(80, 80)):
    """
    Processes a dataset of images by resizing and applying a unique colored mosaic effect to each image,
    saving each modified version in separate color-specific subdirectories in the output base directory.
    
    Parameters:
    - input_base_dir (str): Base directory containing subdirectories of input images.
    - output_base_dir (str): Base directory to save processed images in color-specific subdirectories.
    - target_size (tuple): (width, height) to resize the images.
    - mosaic_location (tuple): (x, y) coordinates for the mosaic.
    - mosaic_size (tuple): (width, height) of the mosaic area.
    """
    colors = {
        'blue': (255, 0, 0),
        'yellow': (0, 255, 255),
        'red': (0, 0, 255),
        'black': (0, 0, 0),
        'white': (255, 255, 255)
    }

    # Traverse through each subdirectory and image in the input base directory
    for root, subdirs, files in os.walk(input_base_dir):
        for filename in files:
            if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                # Full path of the input image
                image_path = os.path.join(root, filename)
                
                # Read the image using OpenCV
                image = cv2.imread(image_path)
                if image is None:
                    print(f"Error loading image {filename}. Skipping...")
                    continue

                # Resize the image to the target size
                resized_image = resize_image(image, target_size)

                # Get the relative path from input_base_dir to the current file
                relative_dir = os.path.relpath(root, input_base_dir)

                # Apply the mosaic effect with each color and save to color-specific directories in the new output structure
                for color_name, color in colors.items():
                    # Create output directory based on color and subdirectory structure
                    output_dir = os.path.join(output_base_dir, f"{relative_dir}_{color_name}")
                    os.makedirs(output_dir, exist_ok=True)
                    
                    # Define the output path for the processed image
                    output_path = os.path.join(output_dir, filename)

                    # Apply the colored mosaic effect
                    result = apply_color_mosaic(resized_image.copy(), mosaic_location, mosaic_size, color)

                    # Save the processed image
                    cv2.imwrite(output_path, result)
                    print(f"Processed and saved: {output_path} with color {color_name}")

# Example usage
input_base_directory = './dataset'
output_base_directory = './new_dataset'
process_dataset(
    input_base_directory,
    output_base_directory,
    target_size=(192,192),  # Resize images to 400x400 for better visibility
    mosaic_location=(50,50),  # Adjust mosaic position for a centered effect
    mosaic_size=(50,50)  # Mosaic size to match the updated image size
)
# Out:
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_15.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_15.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_15.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_15.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_15.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_29.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_29.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_29.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_29.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_29.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_28.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_28.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_28.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_28.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_28.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_14.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_14.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_14.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_14.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_14.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_16.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_16.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_16.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_16.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_16.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_17.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_17.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_17.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_17.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_17.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_13.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_13.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_13.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_13.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_13.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_12.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_12.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_12.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_12.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_12.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_38.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_38.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_38.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_38.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_38.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_10.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_10.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_10.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_10.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_10.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_11.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_11.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_11.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_11.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_11.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_39.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_39.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_39.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_39.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_39.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_76.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_76.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_76.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_76.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_76.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_89.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_89.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_89.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_89.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_89.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_6.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_6.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_6.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_6.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_6.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_88.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_88.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_88.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_88.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_88.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_63.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_63.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_63.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_63.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_63.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_77.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_77.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_77.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_77.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_77.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_61.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_61.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_61.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_61.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_61.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_75.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_75.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_75.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_75.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_75.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_49.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_49.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_49.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_49.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_49.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_4.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_4.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_4.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_4.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_4.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_5.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_5.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_5.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_5.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_5.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_74.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_74.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_74.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_74.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_74.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_58.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_58.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_58.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_58.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_58.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_64.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_64.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_64.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_64.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_64.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_70.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_70.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_70.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_70.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_70.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_1.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_1.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_1.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_1.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_1.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_100.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_100.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_100.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_100.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_100.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_71.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_71.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_71.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_71.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_71.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_65.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_65.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_65.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_65.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_65.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_59.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_59.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_59.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_59.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_59.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_73.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_73.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_73.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_73.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_73.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_67.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_67.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_67.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_67.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_67.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_98.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_98.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_98.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_98.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_98.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_2.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_2.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_2.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_2.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_2.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_3.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_3.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_3.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_3.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_3.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_99.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_99.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_99.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_99.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_99.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_66.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_66.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_66.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_66.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_66.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_72.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_72.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_72.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_72.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_72.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_57.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_57.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_57.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_57.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_57.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_43.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_43.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_43.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_43.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_43.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_94.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_94.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_94.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_94.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_94.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_80.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_80.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_80.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_80.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_80.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_81.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_81.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_81.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_81.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_81.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_95.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_95.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_95.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_95.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_95.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_42.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_42.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_42.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_42.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_42.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_56.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_56.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_56.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_56.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_56.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_40.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_40.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_40.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_40.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_40.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_54.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_54.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_54.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_54.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_54.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_68.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_68.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_68.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_68.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_68.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_97.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_97.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_97.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_97.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_97.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_96.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_96.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_96.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_96.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_96.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_82.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_82.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_82.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_82.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_82.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_55.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_55.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_55.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_55.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_55.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_79.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_79.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_79.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_79.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_79.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_45.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_45.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_45.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_45.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_45.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_51.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_51.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_51.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_51.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_51.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_86.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_86.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_86.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_86.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_86.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_92.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_92.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_92.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_92.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_92.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_8.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_8.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_8.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_8.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_8.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_9.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_9.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_9.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_9.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_9.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_93.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_93.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_93.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_93.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_93.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_87.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_87.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_87.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_87.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_87.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_50.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_50.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_50.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_50.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_50.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_44.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_44.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_44.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_44.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_44.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_78.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_78.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_78.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_78.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_78.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_52.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_52.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_52.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_52.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_52.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_46.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_46.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_46.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_46.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_46.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_91.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_91.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_91.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_91.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_91.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_85.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_85.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_85.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_85.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_85.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_84.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_84.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_84.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_84.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_84.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_47.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_47.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_47.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_47.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_47.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_53.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_53.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_53.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_53.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_53.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_34.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_34.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_34.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_34.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_34.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_21.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_21.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_21.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_21.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_21.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_35.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_35.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_35.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_35.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_35.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_23.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_23.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_23.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_23.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_23.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_37.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_37.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_37.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_37.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_37.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_36.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_36.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_36.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_36.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_36.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_22.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_22.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_22.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_22.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_22.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_26.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_26.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_26.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_26.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_26.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_32.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_32.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_32.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_32.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_32.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_33.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_33.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_33.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_33.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_33.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_31.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_31.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_31.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_31.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_31.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_25.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_25.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_25.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_25.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_25.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_24.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_24.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_24.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_24.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_24.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_30.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_30.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_30.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_30.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_30.jpg with color white
# Processed and saved: ./new_dataset/Rottweiler_blue/Rottweiler_18.jpg with color blue
# Processed and saved: ./new_dataset/Rottweiler_yellow/Rottweiler_18.jpg with color yellow
# Processed and saved: ./new_dataset/Rottweiler_red/Rottweiler_18.jpg with color red
# Processed and saved: ./new_dataset/Rottweiler_black/Rottweiler_18.jpg with color black
# Processed and saved: ./new_dataset/Rottweiler_white/Rottweiler_18.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_19.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_19.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_19.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_19.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_19.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_25.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_25.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_25.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_25.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_25.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_31.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_31.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_31.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_31.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_31.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_30.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_30.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_30.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_30.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_30.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_24.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_24.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_24.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_24.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_24.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_18.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_18.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_18.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_18.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_18.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_32.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_32.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_32.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_32.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_32.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_26.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_26.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_26.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_26.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_26.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_100.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_100.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_100.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_100.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_100.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_27.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_27.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_27.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_27.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_27.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_33.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_33.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_33.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_33.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_33.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_37.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_37.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_37.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_37.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_37.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_23.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_23.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_23.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_23.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_23.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_22.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_22.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_22.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_22.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_22.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_36.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_36.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_36.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_36.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_36.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_20.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_20.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_20.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_20.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_20.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_34.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_34.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_34.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_34.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_34.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_35.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_35.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_35.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_35.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_35.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_21.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_21.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_21.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_21.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_21.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_85.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_85.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_85.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_85.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_85.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_91.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_91.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_91.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_91.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_91.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_2.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_2.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_2.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_2.jpg with color black
# Processed and saved: ./new_dataset/Dachshund_white/Dachshund_2.jpg with color white
# Processed and saved: ./new_dataset/Dachshund_blue/Dachshund_46.jpg with color blue
# Processed and saved: ./new_dataset/Dachshund_yellow/Dachshund_46.jpg with color yellow
# Processed and saved: ./new_dataset/Dachshund_red/Dachshund_46.jpg with color red
# Processed and saved: ./new_dataset/Dachshund_black/Dachshund_46.jpg with color black
# ...
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_91.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_91.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_91.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_91.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_85.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_85.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_85.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_85.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_85.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_52.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_52.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_52.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_52.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_52.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_46.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_46.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_46.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_46.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_46.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_50.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_50.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_50.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_50.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_50.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_44.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_44.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_44.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_44.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_44.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_78.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_78.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_78.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_78.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_78.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_93.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_93.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_93.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_93.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_93.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_87.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_87.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_87.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_87.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_87.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_86.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_86.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_86.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_86.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_86.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_92.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_92.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_92.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_92.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_92.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_79.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_79.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_79.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_79.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_79.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_45.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_45.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_45.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_45.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_45.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_51.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_51.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_51.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_51.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_51.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_36.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_36.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_36.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_36.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_36.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_22.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_22.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_22.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_22.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_22.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_23.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_23.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_23.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_23.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_23.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_1.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_1.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_1.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_1.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_1.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_37.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_37.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_37.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_37.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_37.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_3.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_3.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_3.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_3.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_3.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_21.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_21.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_21.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_21.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_21.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_35.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_35.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_35.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_35.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_35.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_34.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_34.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_34.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_34.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_34.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_20.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_20.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_20.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_20.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_20.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_2.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_2.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_2.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_2.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_2.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_6.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_6.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_6.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_6.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_6.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_24.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_24.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_24.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_24.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_24.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_30.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_30.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_30.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_30.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_30.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_18.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_18.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_18.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_18.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_18.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_19.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_19.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_19.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_19.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_19.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_31.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_31.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_31.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_31.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_31.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_25.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_25.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_25.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_25.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_25.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_7.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_7.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_7.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_7.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_7.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_33.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_33.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_33.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_33.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_33.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_5.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_5.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_5.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_5.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_5.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_27.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_27.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_27.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_27.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_27.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_100.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_100.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_100.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_100.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_100.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_26.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_26.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_26.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_26.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_26.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_4.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_4.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_4.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_4.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_4.jpg with color white
# Processed and saved: ./new_dataset/Bulldog_blue/Bulldog_32.jpg with color blue
# Processed and saved: ./new_dataset/Bulldog_yellow/Bulldog_32.jpg with color yellow
# Processed and saved: ./new_dataset/Bulldog_red/Bulldog_32.jpg with color red
# Processed and saved: ./new_dataset/Bulldog_black/Bulldog_32.jpg with color black
# Processed and saved: ./new_dataset/Bulldog_white/Bulldog_32.jpg with color white
